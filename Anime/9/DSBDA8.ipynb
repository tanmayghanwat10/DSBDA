# %%
import pandas as pd

# %%
import numpy as nm

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df['age']=df['age'].replace(nm.nan,df['age'].mean())

# %%
sns.catplot(x='sex',hue='survived',kind='count',data=df)
# Out:
# C:\Users\Vishw\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
group=df.groupby(['pclass','survived'])

# %%
pclass_survived=group.size().unstack()

# %%
sns.heatmap(pclass_survived,annot=True,fmt="d")
# Out:
# <Axes: xlabel='survived', ylabel='pclass'>

# %%
sns.violinplot(x='sex',y='age',hue='survived',data=df,split=True)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.displot(df['fare'])
# Out:
# C:\Users\Vishw\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['fare'],kde=True)
# Out:
# C:\Users\Vishw\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import seaborn as sns

# %%
import pandas as pd
import numpy as nm
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset('titanic')

# %%
sns.stripplot(x='sex', y='age', data=df, jitter=True)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.stripplot(x='sex', y='age', data=df, jitter=False)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.boxplot(x='sex', y='age', data=df, hue="survived")
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.barplot(x='sex', y='age', data=df, estimator=nm.std)
# Out:
# C:\Users\Vishw\anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.countplot(x='sex', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.histplot(x='sex', y='age', data=df, hue="survived")
sns.hist(x='sex', y='age', data=df, hue="survived")
